# %% [markdown]
# # Визуализация данных по покемонам https://www.kaggle.com/abcsds/pokemon #

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# *Считываем датасет по покемонам:*

# %%
df = pd.read_csv('Pokemon.csv')
df["Type"] = df[["Type 1","Type 2"]].values.tolist()
# Out:
#        #                 Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 0      1            Bulbasaur    Grass  Poison    318  45      49       49
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 1      2              Ivysaur    Grass  Poison    405  60      62       63
# 2      3             Venusaur    Grass  Poison    525  80      82       83
# ..   ...                  ...      ...     ...    ...  ..     ...      ...
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721            Volcanion     Fire   Water    600  80     110      120
# 799  721            Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary     Type
# 0         65       65     45           1      False    Grass
# 0         65       65     45           1      False   Poison
# 1         80       80     60           1      False    Grass
# 1         80       80     60           1      False   Poison
# 2        100      100     80           1      False    Grass
# ..       ...      ...    ...         ...        ...      ...
# 797      150      130     70           6       True    Ghost
# 798      170      130     80           6       True  Psychic
# 798      170      130     80           6       True     Dark
# 799      130       90     70           6       True     Fire
# 799      130       90     70           6       True    Water
#
# [1214 rows x 14 columns]

# %% [markdown]
# ## График по корелляции между полями ##

# %% [markdown]
# *Проверяем зависимость полей. Явная у защиты простой и специальной и еще из видимых между защитой и атакой*

# %%
sns.heatmap(df.corr())

# %% [markdown]
# ## Группы покемонов ##

# %% [markdown]
# ### По поколениям: ###

# %%
plt.figure(figsize = (15,7))
sns.violinplot(x = 'Generation', y='Attack', data = df)

# %% [markdown]
# ### Легендарные и нет: ###

# %%
plt.figure(figsize = (15,7))
sns.violinplot(x = 'Legendary', y='Attack', data = df)

# %% [markdown]
# ## Сравнение по типам: ##

# %% [markdown]
# *Для сравнения по типам нужно подготовить датасет:*

# %%
df_ex = df.explode("Type")
df_ex = df_ex.dropna(subset=["Type"])

#Считаю средние показатели на тип
df_per_Type = df_ex.groupby(by=['Type']).mean().reset_index().merge(df_ex.groupby(by=['Type']).nunique()['#'].reset_index(), how='inner', left_on='Type',right_on ='Type')
df_per_Type.rename(columns={'#_y':'Amount'}, inplace=True)
df_per_Type = df_per_Type.sort_values(by='Amount')

# %% [markdown]
# ### Количество уникальных покемонов на тип: ###

# %%
keys = df_per_Type['Type']
values = df_per_Type['Amount']
plt.pie(values, labels = keys, autopct='%1.2f%%', radius=3,startangle=0)
plt.title("Amount of unique Pokemons", fontsize=16, y=2)
# Out:
# Text(0.5, 2, 'Amount of unique Pokemons')

# %% [markdown]
# ### Показатели защиты и атаки на тип: ###

# %%
fig = px.scatter(df_per_Type, x="Defense", y="Attack", color="Type",
                 size='HP', title="Attack vs Deffence")

fig.show()
# Out:
# <div>                            <div id="2d513d07-aa9a-4454-881e-3f1da8b77ee0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d513d07-aa9a-4454-881e-3f1da8b77ee0")) {                    Plotly.newPlot(                        "2d513d07-aa9a-4454-881e-3f1da8b77ee0",                        [{"hovertemplate": "Type=Ice<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Ice", "marker": {"color": "#636efa", "size": [78.63157894736842], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Ice", "orientation": "v", "showlegend": true, "type": "scatter", "x": [76.65789473684211], "xaxis": "x", "y": [82.05263157894737], "yaxis": "y"}, {"hovertemplate": "Type=Ghost<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Ghost", "marker": {"color": "#EF553B", "size": [62.82608695652174], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Ghost", "orientation": "v", "showlegend": true, "type": "scatter", "x": [81.52173913043478], "xaxis": "x", "y": [76.93478260869566], "yaxis": "y"}, {"hovertemplate": "Type=Fairy<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Fairy", "marker": {"color": "#00cc96", "size": [68.475], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Fairy", "orientation": "v", "showlegend": true, "type": "scatter", "x": [70.4], "xaxis": "x", "y": [61.575], "yaxis": "y"}, {"hovertemplate": "Type=Dragon<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Dragon", "marker": {"color": "#ab63fa", "size": [82.9], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Dragon", "orientation": "v", "showlegend": true, "type": "scatter", "x": [86.62], "xaxis": "x", "y": [105.76], "yaxis": "y"}, {"hovertemplate": "Type=Electric<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Electric", "marker": {"color": "#FFA15A", "size": [63.2], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Electric", "orientation": "v", "showlegend": true, "type": "scatter", "x": [66.54], "xaxis": "x", "y": [69.52], "yaxis": "y"}, {"hovertemplate": "Type=Steel<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Steel", "marker": {"color": "#19d3f3", "size": [64.95918367346938], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Steel", "orientation": "v", "showlegend": true, "type": "scatter", "x": [116.61224489795919], "xaxis": "x", "y": [92.65306122448979], "yaxis": "y"}, {"hovertemplate": "Type=Dark<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Dark", "marker": {"color": "#FF6692", "size": [70.23529411764706], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Dark", "orientation": "v", "showlegend": true, "type": "scatter", "x": [70.94117647058823], "xaxis": "x", "y": [96.7843137254902], "yaxis": "y"}, {"hovertemplate": "Type=Fighting<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgroup": "Fighting", "marker": {"color": "#B6E880", "size": [74.56603773584905], "sizemode": "area", "sizeref": 0.20725000000000002, "symbol": "circle"}, "mode": "markers", "name": "Fighting", "orientation": "v", "showlegend": true, "type": "scatter", "x": [74.05660377358491], "xaxis": "x", "y": [104.66037735849056], "yaxis": "y"}, {"hovertemplate": "Type=Rock<br>Defense=%{x}<br>Attack=%{y}<br>HP=%{marker.size}<extra></extra>", "legendgro ...

# %% [markdown]
# ### Тип покемонов выше среднего по всем показателям: ###

# %%
df_per_Type[(df_per_Type["Attack"]>=df_per_Type["Attack"].mean()) \
            &(df_per_Type["Defense"]>=df_per_Type["Defense"].mean()) \
            &(df_per_Type["Sp. Atk"]>=df_per_Type["Sp. Atk"].mean()) \
            &(df_per_Type["Sp. Def"]>=df_per_Type["Sp. Def"].mean()) \
            &(df_per_Type["HP"]>=df_per_Type["HP"].mean()) \
            &(df_per_Type["Speed"]>=df_per_Type["Speed"].mean())]
# Out:
#      Type     #_x   Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 2  Dragon  477.32  541.76  82.9  105.76    86.62    97.44     86.9  82.14
#
#    Generation  Legendary  Amount
# 2        3.98       0.32      41

# %% [markdown]
# ![DragonUrl](https://i.imgur.com/nVTrsAg.gif "dragon")

# %% [markdown]
# ### Покзатели по поколениям среди топовых типов: ###

# %%
top_fefence = list(df[df['Legendary'] == False].groupby(['Type 1'], as_index=False)[['Defense']].mean().nlargest(5,'Defense')['Type 1'])
top_atac = list(df[df['Legendary'] == False].groupby(['Type 1'], as_index=False)[['Attack']].mean().nlargest(5,'Attack')['Type 1'])

# %%
plt.figure(figsize = (15,7))
plt.title('Top Defence ordinary')
sns.lineplot(data = df[(df['Legendary'] == False)&(df['Type 1'].isin(top_fefence))].groupby(['Generation','Type 1'], as_index=False)[['Defense']].mean(), x='Generation', y='Defense', hue="Type 1")

# %%
plt.figure(figsize = (15,7))
plt.title('Top Atac ordinary')
sns.lineplot(data = df[(df['Legendary'] == False)&(df['Type 1'].isin(top_atac))].groupby(['Generation','Type 1'], as_index=False)[['Attack']].mean(), x='Generation', y='Attack', hue="Type 1")
